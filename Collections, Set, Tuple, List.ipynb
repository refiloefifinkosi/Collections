# %%
student_name = "Amara"
age = 19
subject = "Math"
score = 72
passed = True

print(type(student_name))
print(type(age))
print(type(subject))
print(type(score))
print(type(passed))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
#Mark calculation /100 * 150

final_mark = score/100 * 150 

print(final_mark)
print(type(final_mark))
# Out:
# 108.0
# <class 'float'>

# %%
#List for student names

student_names = ["Amara", "Ben", "Chloe", "David", "Eva", "Farai", "Grace", "Hassan"]
student_names.sort()

print(student_names[0])
print(student_names[-1])
print(student_names[2-5])
print(len(student_names))
# Out:
# Amara
# Hassan
# Farai
# 8

# %%
#List for scores

scores = [72, 55, 88, 45, 91, 63, 50, 77]

print(scores[0])
print(scores[4])
print(scores[0] + scores[4])
# Out:
# 72
# 91
# 163

# %%
#Dictionary for Hassan

hassan = {"name" : "Hassan", "age" : 21, "subject" : "Science", "score" : 77, "passed" : True }

print(hassan["subject"])
print(hassan["score"] + 10)
print(hassan["passed"])
# Out:
# Science
# 87
# True

# %%
#List of student dictionaries

students = [{"name" : "Amara", "age" : 19, "subject" : "Math", "score" : 72, "passed" : True} , {"name" : "Ben", "age" : 21, "subject" : "Science", "score" : 55, "passed" : False }, {"name" : "Chloe", "age" : 20, "subject" : "Math", "score" : 88, "passed" : True }, {"name" : "David", "age" : 22, "subject" : "English", "score" : 45, "passed" : False } ]

print(students[1]["score"])
print(students[0]["name"])
print(len(students))
# Out:
# 55
# Amara
# 4

# %%
#Logic Operators & Conditions

student_name = "Amara"
age = 19
subject = "Math"
score = 72
passed = True

if score > 60 and passed == True:
    print("True")

if age < 18 or score > 70:
    print("True")

if score < 50:
    print("not passed")

    if score > 80 and subject == "Math":
        print("True")
# Out:
# True
# True

# %%
#Score grader code

score = 65
                  
if score > 75:
    print("Distinction")
elif 50 <= score <= 74:
    print("Pass")
else : 
    print("Fail")
# Out:
# Pass

# %%
#Condition tester code

subject = "Math"
score = 35

if subject == "Math" and score >= 60:
    print("Math high achiever")
else:
    print("Does not the criteria")
# Out:
# Does not the criteria

# %%
#No code questions

Dict
